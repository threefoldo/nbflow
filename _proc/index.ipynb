# %% [raw]
# ---
# description: Dialog-based development workflow, inspired by nbdev.
# output-file: index.html
# title: nbflow
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nbflow in Development mode

# %% [markdown]
# ```sh
# # make sure nbflow package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nbflow
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/threefoldo/nbflow.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c threefoldo nbflow
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nbflow
# ```
#
#
# [repo]: https://github.com/threefoldo/nbflow
# [docs]: https://threefoldo.github.io/nbflow/
# [pypi]: https://pypi.org/project/nbflow/
# [conda]: https://anaconda.org/threefoldo/nbflow

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/threefoldo/nbflow
# [docs]: https://threefoldo.github.io/nbflow/
# [pypi]: https://pypi.org/project/nbflow/
# [conda]: https://anaconda.org/threefoldo/nbflow

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
